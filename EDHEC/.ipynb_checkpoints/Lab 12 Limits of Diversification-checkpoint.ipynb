# %%
import edhec_risk_kit as erk
import pandas as pd
import numpy as np
from scipy.optimize import minimize
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi'] = 180
mpl.rcParams['figure.figsize'] = (9, 4)
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False

# %%
ind_returns = erk.get_ind_returns()
ind_nfirms = erk.get_ind_nfirms()
ind_size= erk.get_ind_size()

# %%
ind_nfirms.shape
# Out:
# (1110, 30)

# %%
ind_size.shape
# Out:
# (1110, 30)

# %%
ind_returns.shape
# Out:
# (1110, 30)

# %%
ind_nfirms.head()
# Out:
#          Food  Beer  Smoke  Games  Books  Hshld  Clths  Hlth  Chems  Txtls  \
# 1926-07    43     3     16      7      2      8     12     7     17     13
# 1926-08    43     3     16      7      2      8     12     7     17     13
# 1926-09    43     3     16      7      2      8     12     7     17     13
# 1926-10    43     3     16      7      2      8     12     7     17     13
# 1926-11    43     3     16      7      2      8     12     7     17     13
#
#          ...  Telcm  Servs  BusEq  Paper  Trans  Whlsl  Rtail  Meals  Fin  \
# 1926-07  ...      5      3      7      6     74      2     33      6   12
# 1926-08  ...      5      3      7      6     74      2     33      6   12
# 1926-09  ...      5      3      7      6     74      2     33      6   12
# 1926-10  ...      5      3      7      6     74      2     33      6   12
# 1926-11  ...      5      3      7      6     74      2     33      6   12
#
#          Other
# 1926-07      4
# 1926-08      4
# 1926-09      4
# ...

# %%
ind_mktcap = ind_nfirms * ind_size
ind_mktcap.shape
# Out:
# (1110, 30)

# %%
total_mktcap = ind_mktcap.sum(axis=1)
total_mktcap.plot()
# Out:
# <AxesSubplot:>

# %%
ind_capweight = ind_mktcap.divide(total_mktcap, axis = 0)

# %%
ind_capweight
# Out:
#              Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# 1926-07  0.058037  0.000801  0.035844  0.006935  0.000902  0.006683  0.008265
# 1926-08  0.056578  0.000738  0.035264  0.006932  0.000972  0.006453  0.008673
# 1926-09  0.056699  0.000917  0.036510  0.006810  0.001046  0.006038  0.008249
# 1926-10  0.056920  0.000954  0.036736  0.007175  0.001028  0.006053  0.008139
# 1926-11  0.056725  0.000951  0.038285  0.007047  0.001161  0.005924  0.008396
# ...           ...       ...       ...       ...       ...       ...       ...
# 2018-08  0.021873  0.008309  0.008222  0.011997  0.001168  0.014569  0.009720
# 2018-09  0.021005  0.007873  0.007515  0.011923  0.001076  0.014427  0.009874
# 2018-10  0.020661  0.007862  0.007831  0.011851  0.001052  0.014606  0.010000
# 2018-11  0.022649  0.008403  0.009178  0.010810  0.001066  0.015702  0.009761
# 2018-12  0.022832  0.008763  0.008291  0.010589  0.001083  0.016477  0.009510
#
# ...

# %%
ind_capweight['1926'].sum(axis=1) #previous step done correctly
# Out:
# 1926-07    1.0
# 1926-08    1.0
# 1926-09    1.0
# 1926-10    1.0
# 1926-11    1.0
# 1926-12    1.0
# Freq: M, dtype: float64

# %%
l = ['Fin','Steel']
ind_capweight[l].plot()
# Out:
# <AxesSubplot:>

# %%
total_market_return = (ind_capweight * ind_returns).sum(axis=1)
total_market_return.plot()
# Out:
# <AxesSubplot:>

# %%
total_market_index = erk.drawdown(total_market_return).Wealth
ax = total_market_index.plot()
plt.title("Total Market Cap Weighted Index")
# Out:
# Text(0.5, 1.0, 'Total Market Cap Weighted Index')

# %%
total_market_index["1980":].plot()
total_market_index["1980":].rolling(36).mean().plot()
# Out:
# <AxesSubplot:>

# %%
tmi_tr36rets = total_market_return.rolling(window = 36).aggregate(erk.annualize_rets, periods_per_year = 12)

# %%
tmi_tr36rets.plot(label = "Trailing 36 month return")
total_market_return.plot(label="Total Market Returns")

plt.legend()
plt.show()

# %% [markdown]
# ### Rolling Correlations
# along with MultiIndexes and '.grouby'

# %%
ts_corr = ind_returns.rolling(window=36).corr()
ts_corr.tail()

# notice how it has two indices. Meaning that in 2018-12 the correlations were such:
# Out:
#                    Food      Beer     Smoke     Games     Books     Hshld  \
# 2018-12 Whlsl  0.474948  0.356983  0.122672  0.510425  0.803362  0.419280
#         Rtail  0.517856  0.406107  0.030283  0.676464  0.636320  0.358336
#         Meals  0.370187  0.385483  0.122007  0.301516  0.520649  0.308216
#         Fin    0.298823  0.192706  0.027593  0.480276  0.694812  0.162690
#         Other  0.436952  0.376565  0.224010  0.331829  0.558072  0.390610
#
#                   Clths      Hlth     Chems     Txtls  ...     Telcm  \
# 2018-12 Whlsl  0.570071  0.739764  0.785796  0.634197  ...  0.648092
#         Rtail  0.676598  0.714933  0.626034  0.634202  ...  0.562238
#         Meals  0.302176  0.416193  0.520023  0.491726  ...  0.406184
#         Fin    0.425899  0.658468  0.760151  0.577090  ...  0.420863
#         Other  0.467099  0.645035  0.712511  0.520953  ...  0.607868
#
#                   Servs     BusEq     Paper     Trans     Whlsl     Rtail  \
# ...

# %%
ind_returns.head()
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals     Fin   Other
# ...

# %% [markdown]
# what we want is to look at the average correlation of everything in the market with each other, seen by date
# So we want to see whether correlations hold during market downturns hint: they dont! markets go down in lockstep
# Therefore, lets use pandas group by

# %%
ts_corr.groupby(level=0) #alternatively, can level the index ts_corr.index.names = ['date','industry']
ind_tr36corr = ts_corr.groupby(level=0).apply(lambda cormat: cormat.values.mean())

# %%
ind_tr36corr.plot()
# Out:
# <AxesSubplot:>

# %%
tmi_tr36rets.plot(label = "Trailing 36 months returns", secondary_y=True, color = 'orange')
ind_tr36corr.plot(label = "Trailing 36 months correlations")

plt.show()

# %%
tmi_tr36rets.corr(ind_tr36corr) #the correlation of average correlation of industries and returns is negative!
# as markets fall, correlations increase. Diversification doesn't help against systemic risk.
# Out:
# -0.2801006506288413
