# %%
import edhec_risk_kit as erk
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 180
mpl.rcParams['figure.figsize'] = (9,4)
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ind = pd.read_csv("data/ind30_m_vw_rets.csv",header=0,index_col=0,parse_dates=True)/100

# %%
ind.index = pd.to_datetime(ind.index, format = "%Y%M").to_period("M")

# %%
ind.columns = ind.columns.str.replace(" ","") # or str.strip()
ind.columns
# Out:
# Index(['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other'],
#       dtype='object')

# %%
ind = erk.get_ind_returns()

# %%
erk.drawdown(ind["Food"])["Drawdown"].plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
cols = ["Food","Smoke","Coal","Beer","Fin"]
erk.var_gaussian(ind[cols],modified=True)
# Out:
# Food     0.061207
# Smoke    0.080292
# Coal     0.047359
# Beer     0.033881
# Fin      0.075199
# dtype: float64

# %%
erk.var_gaussian(ind,modified=True).sort_values().tail()
# Out:
# Carry    0.094527
# Meals    0.098403
# BusEq    0.099377
# Games    0.100701
# Mines    0.102782
# dtype: float64

# %%
erk.var_gaussian(ind,modified=True).sort_values().head()
# Out:
# Beer     0.033881
# Coal     0.047359
# Food     0.061207
# Telcm    0.064719
# Hshld    0.064886
# dtype: float64

# %%
erk.var_gaussian(ind,modified=True).sort_values().plot.bar()
# Out:
# <AxesSubplot:>

# %%
annualize_rets(ind,periods_per_year=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-0a901f35f00c> in <module>
# ----> 1 annualize_rets(ind,periods_per_year=4)
#
# NameError: name 'annualize_rets' is not defined

# %%
erk.sharpe_ratio(ind["2000":],0.03,12).sort_values().plot.bar(title="Industry Sharpe Ratios 200-2018",color='goldenrod')
# Out:
# <AxesSubplot:title={'center':'Industry Sharpe Ratios 200-2018'}>

# %%
er = erk.annualize_rets(ind["1995":"2000"],12).sort_values()

# %%
er.plot.bar()
# Out:
# <AxesSubplot:>

# %%
cov = ind["1995":"2000"].cov()
cov.shape
# Out:
# (30, 30)

# %%
cov
# Out:
#            Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# Food   0.002287  0.002077  0.001757  0.000701  0.000886  0.001208  0.001474
# Beer   0.002077  0.004599  0.001143  0.001147  0.000765  0.002447  0.001415
# Smoke  0.001757  0.001143  0.007130  0.000296 -0.000099  0.000981  0.000761
# Games  0.000701  0.001147  0.000296  0.003271  0.001485  0.001018  0.001814
# Books  0.000886  0.000765 -0.000099  0.001485  0.002302  0.000876  0.002037
# Hshld  0.001208  0.002447  0.000981  0.001018  0.000876  0.002849  0.001046
# Clths  0.001474  0.001415  0.000761  0.001814  0.002037  0.001046  0.004896
# Hlth   0.001105  0.001689  0.000877  0.001219  0.000657  0.001253  0.000759
# Chems  0.001253  0.001292  0.000687  0.001547  0.001559  0.001226  0.002547
# Txtls  0.001021  0.001721  0.000555  0.001291  0.001362  0.001172  0.002105
# Cnstr  0.001282  0.001945  0.001181  0.001723  0.001531  0.001770  0.002486
# ...
